# %%
# !node filter2.mjs
# Out:
# {
#   'https://usaaef.org/tools/calculator/save-towards-a-goal-calculator': 'Save Towards a Goal Calculator \nAll Calculators',
#   'https://usaaef.org/news-insights/tag/credit-score': 'Take Charge of Your Credit ScoreSunday April 02, 2023 \n' +
#     'Showing 1 of 1\n' +
#     'Tags\n' +
#     'Basic Allowance for Housing\n' +
#     'Budget\n' +
#     'Budgeting\n' +
#     'Caregiver\n' +
#     'Credit and Debt\n' +
#     'Credit Reports\n' +
#     'Credit Score\n' +
#     'Debt Destroyer\n' +
#     'Emergency Fund\n' +
#     'Estate Planning\n' +
#     'FICO\n' +
#     'Holiday\n' +
#     'Investing\n' +
#     'Life Insurance\n' +
#     'Mental health\n' +
#     'Personal Finance Tips\n' +
#     'Rent or Buy\n' +
#     'Retirement\n' +
#     'Saving\n' +
#     'School\n' +
#     'SGLI\n' +
#     'SMART Goals\n' +
#     'Taxes\n' +
#     'Travel\n' +
#     'Trip Insurance',
# ...
